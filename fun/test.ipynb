# %%
from random import randint
SLEEPTIME = 0.5 # 时间间隔
LENTH0 = 5 # 横长度
LENTH1 = 2 # 竖直长度
DEFAULTKEY = 'W' # 默认方向
DEFAULTVALUE = "*" # 默认地图填充
SNACKHEADICON = "O" 
SNACKBODY = "o"
GAMEMAP = [[DEFAULTVALUE for _ in range(LENTH0)] for _ in range(LENTH1)]

currentkey = DEFAULTKEY
snackhead = [randint(0,LENTH0-1),randint(0,LENTH1-1)] # 蛇头位置(x,y)
print(snackhead[0])
print(snackhead[1])
GAMEMAP[snackhead[1]][snackhead[0]] = 1 # 修改时应为 (y,x)

print(GAMEMAP)
# Out:
# 3
# 0
# [['*', '*', '*', 1, '*'], ['*', '*', '*', '*', '*']]
